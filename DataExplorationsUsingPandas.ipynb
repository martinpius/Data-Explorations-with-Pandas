# %% [markdown]
# # Data explorations with pandas

# %%
#All Credits goes to Data School "You tube Pandas Series Tutorials"

# %%
##Read data from a URL using csv command

# %%
import pandas as pd

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
#Explore the first 6 rows of data

# %%
ufo.head(5)
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
#Explore the diomension of data frame

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
#Explore the missing values 'NaN'

# %%
ufo.isna()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 0      False             True           False  False  False
# 1      False             True           False  False  False
# 2      False             True           False  False  False
# 3      False             True           False  False  False
# 4      False             True           False  False  False
# ...      ...              ...             ...    ...    ...
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False
#
# [18241 rows x 5 columns]

# %%
#Colors reported seems to have a lots of missing obs. Explore the separate series

# %%
ufo['Colors Reported'].isna().value_counts()
# Out:
# True     15359
# False     2882
# Name: Colors Reported, dtype: int64

# %%
#Obtain the simple plot to visualize the missing values

# %%
# %matplotlib inline

# %%
ufo['Colors Reported'].isna().value_counts().plot(kind = 'bar')

# %%
#Handling the missing values by replacing with a special name

# %%
ufo['Colors Reported'].fillna(value = 'OTHERS')
# Out:
# 0        OTHERS
# 1        OTHERS
# 2        OTHERS
# 3        OTHERS
# 4        OTHERS
#           ...
# 18236    OTHERS
# 18237    OTHERS
# 18238    OTHERS
# 18239       RED
# 18240    OTHERS
# Name: Colors Reported, Length: 18241, dtype: object

# %%
#Summarize the ufo data in simple tables

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
#Describe the data by shape of the object

# %%
ufo['State'].groupby(ufo['Shape Reported']).describe()
# Out:
#                count unique top freq
# Shape Reported
# CHEVRON          248     43  CA   40
# CIGAR            617     48  CA   86
# CIRCLE          1365     50  CA  174
# CONE              60     26  CA    6
# CRESCENT           2      2  WI    1
# CROSS             36     14  CA    8
# CYLINDER         294     45  CA   28
# DELTA              7      6  WA    2
# DIAMOND          234     42  CA   36
# DISK            2122     50  CA  287
# DOME               1      1  PA    1
# EGG              197     44  CA   27
# FIREBALL        1039     50  CA  173
# FLARE              1      1  CA    1
# FLASH            188     40  CA   22
# FORMATION        434     48  CA   71
# HEXAGON            1      1  PA    1
# LIGHT           2803     50  CA  394
# OTHER           1402     50  CA  207
# OVAL             845     50  CA  102
# PYRAMID            1      1  MN    1
# RECTANGLE        303     46  CA   41
# ROUND              2      2  CA    1
# SPHERE          1054     50  CA  155
# ...

# %%
#Reset the index by state

# %%
ufo1 = ufo.set_index('State')

# %%
ufo1.head(5)
# Out:
#                        City Colors Reported Shape Reported             Time
# State
# NY                   Ithaca             NaN       TRIANGLE   6/1/1930 22:00
# NJ              Willingboro             NaN          OTHER  6/30/1930 20:00
# CO                  Holyoke             NaN           OVAL  2/15/1931 14:00
# KS                  Abilene             NaN           DISK   6/1/1931 13:00
# NY     New York Worlds Fair             NaN          LIGHT  4/18/1933 19:00

# %%
# Sample the columns with less missing values

# %%
sanp1 = ufo1.iloc[:,[0,2,3]]

# %%
sanp1.head(4)
# Out:
#               City Shape Reported             Time
# State
# NY          Ithaca       TRIANGLE   6/1/1930 22:00
# NJ     Willingboro          OTHER  6/30/1930 20:00
# CO         Holyoke           OVAL  2/15/1931 14:00
# KS         Abilene           DISK   6/1/1931 13:00

# %%
#Obtain a simple plot for the shape reported

# %%
sanp1['Shape Reported'].value_counts().plot(kind = 'bar')

# %%
#Select one state information

# %%
NewYork = ufo[ufo['State']=='NY']

# %%
NewYork.head()
# Out:
#                     City Colors Reported Shape Reported State             Time
# 0                 Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 4   New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
# 41         New York City             NaN           DISK    NY    1/8/1946 2:00
# 50              Syracuse             NaN           DISK    NY  2/20/1947 22:15
# 74              Syracuse             NaN          CIGAR    NY  7/14/1947 10:30

# %%
#Obtain plot  for New York

# %%
NewYork['Shape Reported'].value_counts().plot(kind = 'bar')

# %%
ufo.drop('Colors Reported',axis = 1, inplace = True)

# %%
ufo.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
ufo[ufo['Shape Reported']=='TRIANGLE']['Shape Reported'].value_counts()
# Out:
# TRIANGLE    1889
# Name: Shape Reported, dtype: int64

# %%
#Drops NaN's values

# %%
ufo.dropna(how = 'any')
# Out:
#                        City Shape Reported State              Time
# 0                    Ithaca       TRIANGLE    NY    6/1/1930 22:00
# 1               Willingboro          OTHER    NJ   6/30/1930 20:00
# 2                   Holyoke           OVAL    CO   2/15/1931 14:00
# 3                   Abilene           DISK    KS    6/1/1931 13:00
# 4      New York Worlds Fair          LIGHT    NY   4/18/1933 19:00
# ...                     ...            ...   ...               ...
# 18234              Capitola       TRIANGLE    CA  12/31/2000 22:00
# 18236            Grant Park       TRIANGLE    IL  12/31/2000 23:00
# 18237           Spirit Lake           DISK    IA  12/31/2000 23:00
# 18239           Eagle River          LIGHT    WI  12/31/2000 23:45
# 18240                  Ybor           OVAL    FL  12/31/2000 23:59
#
# [15576 rows x 4 columns]

# %%
#Sort the values by State and indexed by City

# %%
ufo.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
ufo.set_index('Shape Reported').sort_values('State')
# Out:
#                                      City State             Time
# Shape Reported
# CYLINDER                        Anchorage    AK  6/30/1997 12:00
# LIGHT                              Seward    AK   9/2/1999 21:00
# CIRCLE                      Kodiak Island    AK   6/15/1977 2:00
# DISK                            Anchorage    AK  6/10/1949 21:00
# LIGHT                              Nulato    AK  6/15/1975 18:30
# ...                                   ...   ...              ...
# CIRCLE                             Casper    WY  7/25/1976 18:00
# OTHER                             Wyoming    WY   4/20/1983 0:00
# DISK                            Ten Sleep    WY  3/21/1998 20:00
# NaN                              Cheyenne    WY   5/2/1998 20:30
# TRIANGLE        Medicine Bow Natl. Forest    WY   9/5/1998 22:30
#
# [18241 rows x 3 columns]

# %%
#For the UFO'S with missing colors we observe the summary for their shape

# %%
ufo[ufo.City.isnull()]['Shape Reported'].value_counts().plot(kind ='bar')

# %%
#For any missing in any columns we can drops the NaN's by:

# %%
ufo.dropna(subset = ['City','Shape Reported'],how = 'any').head(5)
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dropna(subset = ['City','Shape Reported'],how = 'any').shape
# Out:
# (15576, 4)

# %% [markdown]
# # Numeric data Exploration with Pandas

# %%
# Import another dataset from the web URL which is related to drinks consuptions by countries

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
#Re-index the data by countries and summarize the beer_servings

# %%
drinks.set_index('country')
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# ...

# %%
drinks.beer_servings.groupby(drinks.continent).mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
#Summary stat for the drinks

# %%
drinks.groupby(drinks.continent).mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
#Get the simple plot for the summary drinks

# %%
drinks.groupby(drinks.continent).mean().plot(kind = 'hist')

# %%
drinks[drinks.sort_values('continent')['continent']=='Africa']['beer_servings']
# Out:
# /Users/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# ...
